# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from tensorflow.keras import layers

# %%
df = pd.read_csv("C:\datasets/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['activity'].value_counts()
# Out:
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: activity, dtype: int64

# %%
# lyingRigh과 lyingBack을 lying으로 변환
df['activity'] = df['activity'].replace({'lyingRigh': 'lying', 'lyingBack': 'lying'})

# %%
print(df['activity'].value_counts())
# Out:
# lying                      960
# sitting                    480
# runningTreadmill           480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# walkingTreadmillIncline    480
# standing                   480
# walkingTreadmillFlat       480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# basketBall                 480
# Name: activity, dtype: int64

# %%
df_filtered = df[df['activity'].isin(['sitting', 'lying'])]
df_filtered = df_filtered.drop('people', axis = 1)
df_filtered
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025     -9.3424    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851     -9.3657    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350     -9.3628    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014     -9.3649    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614     -9.3661    -9.42790    0.000167  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 1915  9.195642e-05     0.009589      0.401254     -0.410987    -0.382210
# 1916  7.375030e-05     0.008588      0.147180     -0.411248    -0.365810
# 1917  3.380089e-05     0.005814      0.032341     -0.409787    -0.379260
# 1918  9.044032e-05     0.009510      0.409508     -0.409101    -0.360740
# 1919  9.748789e-05     0.009874      0.413339     -0.410440    -0.385880
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729   sitting
# 1       -0.059589  7.032302e-07     0.000839      0.347471   sitting
# 2       -0.059065  6.268222e-07     0.000792      0.045579   sitting
# 3       -0.058310  8.011245e-07     0.000895      0.240690   sitting
# 4       -0.057815  6.853423e-07     0.000828      0.258429   sitting
# ...           ...           ...          ...           ...       ...
# 1915    -0.446050  9.935077e-05     0.009967     -0.597598     lying
# 1916    -0.436760  8.659481e-05     0.009306      1.021454     lying
# 1917    -0.434310  7.258946e-05     0.008520      0.431012     lying
# 1918    -0.440870  1.127801e-04     0.010620      1.368666     lying
# 1919    -0.438410  7.216993e-05     0.008495      0.054973     lying
#
# [1440 rows x 271 columns]

# %%
df_filtered['activity'].value_counts()
# Out:
# lying      960
# sitting    480
# Name: activity, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
df_filtered['activity'] = label_encoder.fit_transform(df_filtered['activity'])

df_filtered
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025     -9.3424    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851     -9.3657    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350     -9.3628    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014     -9.3649    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614     -9.3661    -9.42790    0.000167  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0     6.267229e-07     0.000792      0.177075     -0.057119    -0.054963
# 1     7.403458e-07     0.000860     -0.286918     -0.057268    -0.054945
# 2     5.802523e-07     0.000762     -0.134430     -0.057068    -0.054711
# 3     5.398837e-07     0.000735      0.021485     -0.056422    -0.053670
# 4     6.787533e-07     0.000824     -0.148229     -0.055801    -0.053313
# ...            ...          ...           ...           ...          ...
# 1915  9.195642e-05     0.009589      0.401254     -0.410987    -0.382210
# 1916  7.375030e-05     0.008588      0.147180     -0.411248    -0.365810
# 1917  3.380089e-05     0.005814      0.032341     -0.409787    -0.379260
# 1918  9.044032e-05     0.009510      0.409508     -0.409101    -0.360740
# 1919  9.748789e-05     0.009874      0.413339     -0.410440    -0.385880
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0       -0.059241  6.778722e-07     0.000823      0.036729         1
# 1       -0.059589  7.032302e-07     0.000839      0.347471         1
# 2       -0.059065  6.268222e-07     0.000792      0.045579         1
# 3       -0.058310  8.011245e-07     0.000895      0.240690         1
# 4       -0.057815  6.853423e-07     0.000828      0.258429         1
# ...           ...           ...          ...           ...       ...
# 1915    -0.446050  9.935077e-05     0.009967     -0.597598         0
# 1916    -0.436760  8.659481e-05     0.009306      1.021454         0
# 1917    -0.434310  7.258946e-05     0.008520      0.431012         0
# 1918    -0.440870  1.127801e-04     0.010620      1.368666         0
# 1919    -0.438410  7.216993e-05     0.008495      0.054973         0
#
# [1440 rows x 271 columns]

# %%
LABELS = ["Normal", "Abnormal"]

# %%
count_classes = df_filtered.value_counts(df['activity'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df_filtered[df_filtered.activity == 1]
normal = df_filtered[df_filtered.activity == 0]
frauds.shape
# Out:
# (480, 271)

# %%
normal.shape
# Out:
# (960, 271)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df_filtered, test_size=0.2, random_state=20)

X_train.head()
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 251      6.907151      6.9812     6.80220    0.001179    0.034335
# 1014    -4.634902     -4.5576    -4.70720    0.001062    0.032595
# 1123    -3.409643     -3.3525    -3.44950    0.000450    0.021217
# 255      6.912211      6.9887     6.80960    0.001304    0.036109
# 1739    -0.526025     -0.4724    -0.58415    0.000481    0.021937
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 251     -0.738872    -0.492903    -0.44488   -0.556230    0.000400  ...
# 1014    -0.022600    -0.661550    -0.60246   -0.749640    0.000870  ...
# 1123     0.131701     0.089917     0.17925   -0.013255    0.000816  ...
# 255     -0.259652    -0.480467    -0.41502   -0.563900    0.000658  ...
# 1739    -0.224470    -9.782885    -9.70040   -9.899600    0.000914  ...
#
#        LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 251   4.446731e-07     0.000667     -0.094248      0.289049      0.29101
# 1014  4.187223e-07     0.000647      0.278959     -0.525365     -0.52338
# 1123  6.329016e-07     0.000796      0.109761      0.958187      0.95964
# 255   4.680509e-07     0.000684      0.076878      0.288878      0.29097
# 1739  5.670998e-07     0.000753     -0.023755     -0.615915     -0.61433
#
#       LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 251       0.28730  5.273868e-07     0.000726      0.247532         1
# 1014     -0.52752  5.237589e-07     0.000724      0.128404         0
# 1123      0.95647  4.227273e-07     0.000650     -0.108056         0
# 255       0.28692  6.552235e-07     0.000809      0.021481         1
# 1739     -0.61733  4.237524e-07     0.000651     -0.076690         0
#
# [5 rows x 271 columns]

# %%
X_train = X_train[X_train.activity == 0]

y_train = X_train['activity']
y_test = X_test['activity']

X_train = X_train.drop(['activity'], axis=1)
X_test = X_test.drop(['activity'], axis=1)

X_train
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 1014    -4.634902    -4.55760    -4.70720    0.001062    0.032595
# 1123    -3.409643    -3.35250    -3.44950    0.000450    0.021217
# 1739    -0.526025    -0.47240    -0.58415    0.000481    0.021937
# 1621     1.377745     1.45280     1.30350    0.000999    0.031604
# 1126    -3.482634    -3.27030    -3.65750    0.004737    0.068826
# ...           ...         ...         ...         ...         ...
# 1908     2.615501     2.65270     2.57710    0.000193    0.013907
# 1722    -0.573965    -0.53322    -0.62313    0.000382    0.019550
# 1404    -1.708773    -1.64450    -1.78080    0.001219    0.034918
# 1727    -0.549961    -0.47365    -0.60789    0.000854    0.029227
# 1859     0.374031     0.42693     0.33736    0.000366    0.019142
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 1014    -0.022600    -0.661550    -0.60246   -0.749640    0.000870  ...
# 1123     0.131701     0.089917     0.17925   -0.013255    0.000816  ...
# 1739    -0.224470    -9.782885    -9.70040   -9.899600    0.000914  ...
# 1621    -0.086084    -7.159021    -7.04850   -7.292300    0.003269  ...
# 1126    -0.061431     0.104506     0.38740   -0.176550    0.005428  ...
# ...           ...          ...         ...         ...         ...  ...
# 1908    -0.316697    -9.393974    -9.34970   -9.422400    0.000170  ...
# 1722    -0.268467    -9.755309    -9.68750   -9.865300    0.000733  ...
# 1404     0.014185    -2.296489    -2.21340   -2.399400    0.001017  ...
# 1727     0.253378    -9.760238    -9.63570   -9.865000    0.001462  ...
# 1859     0.282731    -8.410632    -8.34070   -8.503100    0.001255  ...
#
#       LL_ymag_min   LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# 1014      0.56874  4.187223e-07     0.000647      0.278959     -0.525365
# 1123      0.15655  6.329016e-07     0.000796      0.109761      0.958187
# 1739     -0.24838  5.670998e-07     0.000753     -0.023755     -0.615915
# 1621     -0.47861  1.425414e-06     0.001194     -0.197761     -0.451662
# 1126      0.18712  6.866827e-06     0.002620      0.408001      0.953577
# ...           ...           ...          ...           ...           ...
# 1908     -0.54617  8.157775e-05     0.009032      0.184982     -0.411386
# 1722     -0.24918  7.020958e-07     0.000838      0.034115     -0.614781
# 1404      0.31915  1.068923e-04     0.010339      0.148356     -0.638062
# 1727     -0.24864  5.190850e-07     0.000720     -0.038855     -0.614830
# 1859     -0.44417  6.369798e-07     0.000798      0.053394     -0.853205
#
#       LL_zmag_max  LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 1014     -0.52338     -0.52752  5.237589e-07     0.000724      0.128404
# 1123      0.95964      0.95647  4.227273e-07     0.000650     -0.108056
# 1739     -0.61433     -0.61733  4.237524e-07     0.000651     -0.076690
# 1621     -0.44930     -0.45347  6.531650e-07     0.000808      0.044336
# 1126      0.95572      0.95179  6.165219e-07     0.000785      0.162851
# ...           ...          ...           ...          ...           ...
# 1908     -0.37905     -0.43545  8.429205e-05     0.009181      0.321726
# 1722     -0.61310     -0.61652  4.993076e-07     0.000707     -0.144932
# 1404     -0.59517     -0.66246  8.761269e-05     0.009360      0.781610
# 1727     -0.61320     -0.61668  4.595047e-07     0.000678     -0.010921
# 1859     -0.85160     -0.85511  4.040558e-07     0.000636      0.066421
#
# [770 rows x 270 columns]

# %%
X_train.shape
# Out:
# (770, 270)

# %%
# X_train과 X_test를 넘파이 배열로 변환
X_train = X_train.values
X_test = X_test.values

X_train
# Out:
# array([[-4.63490160e+00, -4.55760000e+00, -4.70720000e+00, ...,
#          5.23758942e-07,  7.23711919e-04,  1.28404286e-01],
#        [-3.40964320e+00, -3.35250000e+00, -3.44950000e+00, ...,
#          4.22727329e-07,  6.50174845e-04, -1.08055791e-01],
#        [-5.26025360e-01, -4.72400000e-01, -5.84150000e-01, ...,
#          4.23752426e-07,  6.50962692e-04, -7.66900427e-02],
#        ...,
#        [-1.70877280e+00, -1.64450000e+00, -1.78080000e+00, ...,
#          8.76126937e-05,  9.36016526e-03,  7.81610289e-01],
#        [-5.49961120e-01, -4.73650000e-01, -6.07890000e-01, ...,
#          4.59504735e-07,  6.77867786e-04, -1.09212871e-02],
#        [ 3.74031040e-01,  4.26930000e-01,  3.37360000e-01, ...,
#          4.04055845e-07,  6.35653872e-04,  6.64209337e-02]])

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 14  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용

history = autoencoder.fit(X_train, X_train, 
                          epochs=50, 
                          batch_size=256, 
                          shuffle=True, 
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 3s 231ms/step - loss: 5.7695 - val_loss: 5.6686
# Epoch 2/50
# 3/3 [==============================] - 0s 58ms/step - loss: 5.7633 - val_loss: 5.6620
# Epoch 3/50
# 3/3 [==============================] - 0s 52ms/step - loss: 5.7556 - val_loss: 5.6535
# Epoch 4/50
# 3/3 [==============================] - 0s 51ms/step - loss: 5.7458 - val_loss: 5.6432
# Epoch 5/50
# 3/3 [==============================] - 0s 53ms/step - loss: 5.7344 - val_loss: 5.6309
# Epoch 6/50
# 3/3 [==============================] - 0s 51ms/step - loss: 5.7208 - val_loss: 5.6159
# Epoch 7/50
# 3/3 [==============================] - 0s 51ms/step - loss: 5.7043 - val_loss: 5.5979
# Epoch 8/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.6847 - val_loss: 5.5767
# Epoch 9/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.6619 - val_loss: 5.5525
# Epoch 10/50
# 3/3 [==============================] - 0s 51ms/step - loss: 5.6355 - val_loss: 5.5249
# Epoch 11/50
# 3/3 [==============================] - 0s 51ms/step - loss: 5.6054 - val_loss: 5.4935
# Epoch 12/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.5716 - val_loss: 5.4588
# Epoch 13/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.5344 - val_loss: 5.4208
# Epoch 14/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.4943 - val_loss: 5.3797
# Epoch 15/50
# 3/3 [==============================] - 0s 52ms/step - loss: 5.4511 - val_loss: 5.3361
# Epoch 16/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.4062 - val_loss: 5.2912
# Epoch 17/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.3603 - val_loss: 5.2455
# Epoch 18/50
# 3/3 [==============================] - 0s 67ms/step - loss: 5.3148 - val_loss: 5.2001
# Epoch 19/50
# 3/3 [==============================] - 0s 52ms/step - loss: 5.2701 - val_loss: 5.1562
# Epoch 20/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.2275 - val_loss: 5.1148
# Epoch 21/50
# 3/3 [==============================] - 0s 49ms/step - loss: 5.1879 - val_loss: 5.0764
# Epoch 22/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.1514 - val_loss: 5.0415
# Epoch 23/50
# 3/3 [==============================] - 0s 49ms/step - loss: 5.1187 - val_loss: 5.0105
# Epoch 24/50
# 3/3 [==============================] - 0s 52ms/step - loss: 5.0897 - val_loss: 4.9833
# Epoch 25/50
# 3/3 [==============================] - 0s 51ms/step - loss: 5.0646 - val_loss: 4.9600
# Epoch 26/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.0433 - val_loss: 4.9402
# Epoch 27/50
# 3/3 [==============================] - 0s 50ms/step - loss: 5.0254 - val_loss: 4.9237
# Epoch 28/50
# 3/3 [==============================] - 0s 49ms/step - loss: 5.0106 - val_loss: 4.9101
# Epoch 29/50
# 3/3 [==============================] - 0s 50ms/step - loss: 4.9987 - val_loss: 4.8990
# Epoch 30/50
# 3/3 [==============================] - 0s 51ms/step - loss: 4.9890 - val_loss: 4.8900
# Epoch 31/50
# 3/3 [==============================] - 0s 53ms/step - loss: 4.9813 - val_loss: 4.8827
# Epoch 32/50
# 3/3 [==============================] - 0s 52ms/step - loss: 4.9750 - val_loss: 4.8769
# Epoch 33/50
# 3/3 [==============================] - 0s 52ms/step - loss: 4.9702 - val_loss: 4.8721
# Epoch 34/50
# 3/3 [==============================] - 0s 57ms/step - loss: 4.9661 - val_loss: 4.8681
# Epoch 35/50
# 3/3 [==============================] - 0s 58ms/step - loss: 4.9628 - val_loss: 4.8649
# Epoch 36/50
# 3/3 [==============================] - 0s 55ms/step - loss: 4.9600 - val_loss: 4.8620
# Epoch 37/50
# 3/3 [==============================] - 0s 53ms/step - loss: 4.9576 - val_loss: 4.8594
# Epoch 38/50
# 3/3 [==============================] - 0s 59ms/step - loss: 4.9554 - val_loss: 4.8571
# Epoch 39/50
# 3/3 [==============================] - 0s 46ms/step - loss: 4.9533 - val_loss: 4.8549
# Epoch 40/50
# 3/3 [==============================] - 0s 49ms/step - loss: 4.9514 - val_loss: 4.8527
# Epoch 41/50
# 3/3 [==============================] - 0s 50ms/step - loss: 4.9495 - val_loss: 4.8507
# Epoch 42/50
# 3/3 [==============================] - 0s 57ms/step - loss: 4.9477 - val_loss: 4.8488
# Epoch 43/50
# 3/3 [==============================] - 0s 61ms/step - loss: 4.9461 - val_loss: 4.8471
# Epoch 44/50
# 3/3 [==============================] - 0s 51ms/step - loss: 4.9446 - val_loss: 4.8455
# Epoch 45/50
# 3/3 [==============================] - 0s 52ms/step - loss: 4.9434 - val_loss: 4.8441
# Epoch 46/50
# 3/3 [==============================] - 0s 49ms/step - loss: 4.9423 - val_loss: 4.8428
# Epoch 47/50
# 3/3 [==============================] - 0s 59ms/step - loss: 4.9412 - val_loss: 4.8417
# Epoch 48/50
# 3/3 [==============================] - 0s 54ms/step - loss: 4.9403 - val_loss: 4.8405
# Epoch 49/50
# 3/3 [==============================] - 0s 50ms/step - loss: 4.9393 - val_loss: 4.8394
# Epoch 50/50
# 3/3 [==============================] - 0s 51ms/step - loss: 4.9384 - val_loss: 4.8384

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 9/9 [==============================] - 0s 4ms/step
#        reconstruction_error  true_class
# count            288.000000  288.000000
# mean               4.863563    0.340278
# std                0.232969    0.474627
# min                4.557280    0.000000
# 25%                4.670693    0.000000
# 50%                4.828094    0.000000
# 75%                4.975827    1.000000
# max                5.839453    1.000000

# %%
threshold = np.percentile(error_df['reconstruction_error'], 95)  # 95번째 백분위수

threshold
# Out:
# 5.229237097108616

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(error_df['true_class'], error_df['reconstruction_error'])
optimal_idx = np.argmax(tpr - fpr)  # TPR - FPR이 최대가 되는 곳
optimal_threshold = thresholds[optimal_idx]

optimal_threshold
# Out:
# 4.736719071845364

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.93      0.76       190
#            1       0.07      0.01      0.02        98
#
#     accuracy                           0.61       288
#    macro avg       0.36      0.47      0.39       288
# weighted avg       0.45      0.61      0.51       288
