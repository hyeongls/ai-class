# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from tensorflow.keras import layers

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
df = pd.read_csv("C:\datasets/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
df['activity'] = label_encoder.fit_transform(df['activity'])

# %%
df = df.drop('people', axis = 1)

# %%
df.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729        12
# 1  7.032302e-07     0.000839      0.347471        12
# 2  6.268222e-07     0.000792      0.045579        12
# 3  8.011245e-07     0.000895      0.240690        12
# 4  6.853423e-07     0.000828      0.258429        12
#
# [5 rows x 271 columns]

# %%
df['activity'].value_counts()
# Out:
# 12    480
# 18    480
# 6     480
# 10    480
# 4     480
# 3     480
# 2     480
# 15    480
# 11    480
# 17    480
# 13    480
# 16    480
# 9     480
# 14    480
# 5     480
# 0     480
# 8     480
# 7     480
# 1     480
# Name: activity, dtype: int64

# %%
X = df.drop('activity', axis=1)
y = df['activity']

X
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_min   LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# 0         0.29968  6.267229e-07     0.000792      0.177075     -0.057119
# 1         0.29974  7.403458e-07     0.000860     -0.286918     -0.057268
# 2         0.30068  5.802523e-07     0.000762     -0.134430     -0.057068
# 3         0.30088  5.398837e-07     0.000735      0.021485     -0.056422
# 4         0.30041  6.787533e-07     0.000824     -0.148229     -0.055801
# ...           ...           ...          ...           ...           ...
# 9115      0.19482  4.033226e-02     0.200829     -0.040701      0.297666
# 9116      0.21407  2.212497e-02     0.148745     -0.266377      0.224716
# 9117     -0.47131  9.656444e-02     0.310748     -0.009505     -0.237786
# 9118     -0.17806  2.448990e-02     0.156493      0.050624      0.533023
# 9119     -0.27751  5.251176e-02     0.229154     -0.342228      0.491919
#
#       LL_zmag_max  LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 0       -0.054963    -0.059241  6.778722e-07     0.000823      0.036729
# 1       -0.054945    -0.059589  7.032302e-07     0.000839      0.347471
# 2       -0.054711    -0.059065  6.268222e-07     0.000792      0.045579
# 3       -0.053670    -0.058310  8.011245e-07     0.000895      0.240690
# 4       -0.053313    -0.057815  6.853423e-07     0.000828      0.258429
# ...           ...          ...           ...          ...           ...
# 9115     0.708480    -0.117430  4.135451e-02     0.203358     -0.310022
# 9116     0.554670    -0.250950  3.355704e-02     0.183186     -0.736410
# 9117     0.088854    -0.477260  2.026107e-02     0.142341      0.668438
# 9118     0.677800     0.055941  1.356379e-02     0.116464     -1.482489
# 9119     0.707920     0.251280  9.358254e-03     0.096738     -0.223302
#
# [9120 rows x 270 columns]

# %%
y
# Out:
# 0       12
# 1       12
# 2       12
# 3       12
# 4       12
#         ..
# 9115     1
# 9116     1
# 9117     1
# 9118     1
# 9119     1
# Name: activity, Length: 9120, dtype: int32

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    test_size = 0.25, 
                                                    random_state = 21)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6840, 270), (2280, 270), (6840,), (2280,))

# %%
n_classes = 19

# %%
X_train
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 3732     9.045058     12.5980      6.8648    0.356080    0.596724
# 5020     9.611005     15.4780      5.3898    5.147909    2.268900
# 8229     9.805531     31.3150    -10.9710   62.042647    7.876716
# 2820     9.812606     19.3360      5.5398    8.655628    2.942045
# 3602     8.898481      9.4089      8.7239    0.027789    0.166701
# ...           ...         ...         ...         ...         ...
# 6844     9.457370     10.6610      8.5149    0.101378    0.318399
# 48       7.854082      7.9661      7.7720    0.001740    0.041717
# 8964     8.906275     35.1080    -11.4280   27.192146    5.214609
# 5944    -7.098566     -3.6086    -14.6730    3.784878    1.945476
# 5327     9.868501     47.9140     -4.9022  155.583344   12.473305
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 3732     1.323620    -1.437671    -0.34324     -3.1539    0.116414  ...
# 5020     0.574077     0.447448     3.38570     -1.6249    1.342423  ...
# 8229     0.512634    -0.410492     2.64600     -3.5750    0.937097  ...
# 2820     1.147825     0.163492     3.91210     -3.6118    2.972370  ...
# 3602     1.788558     0.472501     0.56402      0.3089    0.002374  ...
# ...           ...          ...         ...         ...         ...  ...
# 6844     0.537069    -1.007668     1.03380     -3.0779    1.057614  ...
# 48       0.357780     1.456251     1.54940      1.3859    0.000650  ...
# 8964     0.613814     0.093911     5.93800     -5.2945    2.845590  ...
# 5944    -1.132308     4.906652     9.64780      1.6109    2.477244  ...
# 5327     1.228975     0.782757    16.91800    -18.3170   28.348554  ...
#
#       LL_ymag_min   LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# 3732    -0.418490  8.112788e-04     0.028483      2.877865      0.299330
# 5020     0.229580  7.489577e-02     0.273671     -0.330071     -0.088240
# 8229    -0.444370  2.236682e-03     0.047294      0.476774      0.466038
# 2820    -0.609370  7.223352e-03     0.084990      0.351297      0.527618
# 3602    -0.036769  9.588773e-04     0.030966     -0.267793     -0.093108
# ...           ...           ...          ...           ...           ...
# 6844     0.372660  7.690415e-03     0.087695     -0.334048      0.139854
# 48       0.302470  6.782681e-07     0.000824      0.045344     -0.056929
# 8964     0.471420  1.113635e-02     0.105529     -0.110430      0.286578
# 5944     0.281900  4.031211e-02     0.200779     -0.049145      0.594795
# 5327     0.160760  2.352085e-02     0.153365     -0.467181      0.115811
#
#       LL_zmag_max  LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 3732     0.354630    -0.329960  2.050064e-02     0.143180     -3.357413
# 5020     0.043270    -0.281280  6.578364e-03     0.081107     -0.446036
# 8229     0.531940     0.330420  1.223714e-03     0.034982     -1.071766
# 2820     0.599300     0.436330  1.770409e-03     0.042076     -0.444571
# 3602     0.058554    -0.218350  6.881565e-03     0.082955      0.090125
# ...           ...          ...           ...          ...           ...
# 6844     0.222630     0.062923  2.258485e-03     0.047524      0.027529
# 48      -0.053780    -0.058725  6.989429e-07     0.000836      0.645278
# 8964     0.623030     0.115330  1.227737e-02     0.110803      1.016814
# 5944     0.709910     0.410630  6.334717e-03     0.079591     -0.522296
# 5327     0.344180    -0.012856  4.953541e-03     0.070381      0.395626
#
# [6840 rows x 270 columns]

# %%
input_shape = (270, 1)

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=2,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)


model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 270, 1)]     0           []
#
#  multi_head_attention (MultiHea  (None, 270, 1)      7169        ['input_1[0][0]',
#  dAttention)                                                      'input_1[0][0]']
#
#  dropout (Dropout)              (None, 270, 1)       0           ['multi_head_attention[0][0]']
#
#  layer_normalization (LayerNorm  (None, 270, 1)      2           ['dropout[0][0]']
#  alization)
#
#  tf.__operators__.add (TFOpLamb  (None, 270, 1)      0           ['layer_normalization[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  conv1d (Conv1D)                (None, 270, 4)       8           ['tf.__operators__.add[0][0]']
#
#  dropout_1 (Dropout)            (None, 270, 4)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 270, 1)       5           ['dropout_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 270, 1)      2           ['conv1d_1[0][0]']
#  rmalization)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 270, 1)      0           ['layer_normalization_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  multi_head_attention_1 (MultiH  (None, 270, 1)      7169        ['tf.__operators__.add_1[0][0]',
#  eadAttention)                                                    'tf.__operators__.add_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 270, 1)       0           ['multi_head_attention_1[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 270, 1)      2           ['dropout_2[0][0]']
#  rmalization)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 270, 1)      0           ['layer_normalization_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 270, 4)       8           ['tf.__operators__.add_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 270, 4)       0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 270, 1)       5           ['dropout_3[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 270, 1)      2           ['conv1d_3[0][0]']
#  rmalization)
#
#  tf.__operators__.add_3 (TFOpLa  (None, 270, 1)      0           ['layer_normalization_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  global_average_pooling1d (Glob  (None, 1)           0           ['tf.__operators__.add_3[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          256         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 19)           2451        ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 17,079
# Trainable params: 17,079
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=64,
    callbacks=callbacks,
)

model.evaluate(x_test, y_test, verbose=1)
# Out:
# Epoch 1/20
# 86/86 [==============================] - 180s 2s/step - loss: 2.8996 - sparse_categorical_accuracy: 0.0731 - val_loss: 2.8637 - val_sparse_categorical_accuracy: 0.0980
# Epoch 2/20
# 86/86 [==============================] - 199s 2s/step - loss: 2.8630 - sparse_categorical_accuracy: 0.1001 - val_loss: 2.8269 - val_sparse_categorical_accuracy: 0.1009
# Epoch 3/20
# 86/86 [==============================] - 235s 3s/step - loss: 2.8251 - sparse_categorical_accuracy: 0.1131 - val_loss: 2.7922 - val_sparse_categorical_accuracy: 0.1096
# Epoch 4/20
# 86/86 [==============================] - 262s 3s/step - loss: 2.7951 - sparse_categorical_accuracy: 0.1162 - val_loss: 2.7575 - val_sparse_categorical_accuracy: 0.1177
# Epoch 5/20
# 55/86 [==================>...........] - ETA: 59:13 - loss: 2.7661 - sparse_categorical_accuracy: 0.1185
