# %%
# 딥러닝은 encoding 필수
#1. label encoding
#2. one-hot encoding
#3. numpy

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:\datasets/diabetes.csv", header=0)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X = df.drop('Outcome', axis = 1)
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
Y = df['Outcome']
Y = pd.get_dummies(Y).values

# %%
X = X.values
X
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
# array([[7.00e+00, 1.50e+02, 7.80e+01, ..., 3.52e+01, 6.92e-01, 5.40e+01],
#        [4.00e+00, 9.70e+01, 6.00e+01, ..., 2.82e+01, 4.43e-01, 2.20e+01],
#        [0.00e+00, 1.65e+02, 9.00e+01, ..., 5.23e+01, 4.27e-01, 2.30e+01],
#        ...,
#        [4.00e+00, 9.40e+01, 6.50e+01, ..., 2.47e+01, 1.48e-01, 2.10e+01],
#        [1.10e+01, 8.50e+01, 7.40e+01, ..., 3.01e+01, 3.00e-01, 3.50e+01],
#        [5.00e+00, 1.36e+02, 8.20e+01, ..., 0.00e+00, 6.40e-01, 6.90e+01]])

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

model = Sequential()

model.add(Dense(10,input_shape =(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(Adam(lr= 0.04),'binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 10)                90
#
#  dense_21 (Dense)            (None, 8)                 88
#
#  dense_22 (Dense)            (None, 6)                 54
#
#  dense_23 (Dense)            (None, 2)                 14
#
# =================================================================
# Total params: 246
# Trainable params: 246
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 1s 8ms/step - loss: 1.1475 - accuracy: 0.6059 - val_loss: 0.6350 - val_accuracy: 0.6948
# Epoch 2/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6540 - accuracy: 0.6401 - val_loss: 0.6189 - val_accuracy: 0.6948
# Epoch 3/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6543 - accuracy: 0.6401 - val_loss: 0.6186 - val_accuracy: 0.6948
# Epoch 4/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.6401 - val_loss: 0.6225 - val_accuracy: 0.6948
# Epoch 5/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6539 - accuracy: 0.6401 - val_loss: 0.6230 - val_accuracy: 0.6948
# Epoch 6/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6540 - accuracy: 0.6401 - val_loss: 0.6234 - val_accuracy: 0.6948
# Epoch 7/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6537 - accuracy: 0.6401 - val_loss: 0.6225 - val_accuracy: 0.6948
# Epoch 8/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6541 - accuracy: 0.6401 - val_loss: 0.6199 - val_accuracy: 0.6948
# Epoch 9/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6540 - accuracy: 0.6401 - val_loss: 0.6195 - val_accuracy: 0.6948
# Epoch 10/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6544 - accuracy: 0.6401 - val_loss: 0.6213 - val_accuracy: 0.6948
# Epoch 11/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6401 - val_loss: 0.6241 - val_accuracy: 0.6948
# Epoch 12/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6536 - accuracy: 0.6401 - val_loss: 0.6211 - val_accuracy: 0.6948
# Epoch 13/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6543 - accuracy: 0.6401 - val_loss: 0.6212 - val_accuracy: 0.6948
# Epoch 14/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.6401 - val_loss: 0.6235 - val_accuracy: 0.6948
# Epoch 15/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6541 - accuracy: 0.6401 - val_loss: 0.6226 - val_accuracy: 0.6948
# Epoch 16/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6538 - accuracy: 0.6401 - val_loss: 0.6221 - val_accuracy: 0.6948
# Epoch 17/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6401 - val_loss: 0.6236 - val_accuracy: 0.6948
# Epoch 18/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6547 - accuracy: 0.6401 - val_loss: 0.6181 - val_accuracy: 0.6948
# Epoch 19/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.6401 - val_loss: 0.6219 - val_accuracy: 0.6948
# Epoch 20/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6535 - accuracy: 0.6401 - val_loss: 0.6199 - val_accuracy: 0.6948
# Epoch 21/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6545 - accuracy: 0.6401 - val_loss: 0.6226 - val_accuracy: 0.6948
# Epoch 22/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6541 - accuracy: 0.6401 - val_loss: 0.6192 - val_accuracy: 0.6948
# Epoch 23/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6533 - accuracy: 0.6401 - val_loss: 0.6229 - val_accuracy: 0.6948
# Epoch 24/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6541 - accuracy: 0.6401 - val_loss: 0.6262 - val_accuracy: 0.6948
# Epoch 25/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6538 - accuracy: 0.6401 - val_loss: 0.6208 - val_accuracy: 0.6948
# Epoch 26/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6537 - accuracy: 0.6401 - val_loss: 0.6223 - val_accuracy: 0.6948
# Epoch 27/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6537 - accuracy: 0.6401 - val_loss: 0.6187 - val_accuracy: 0.6948
# Epoch 28/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.6401 - val_loss: 0.6213 - val_accuracy: 0.6948
# Epoch 29/30
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6536 - accuracy: 0.6401 - val_loss: 0.6246 - val_accuracy: 0.6948
# Epoch 30/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6540 - accuracy: 0.6401 - val_loss: 0.6225 - val_accuracy: 0.6948
# 5/5 [==============================] - 0s 998us/step
